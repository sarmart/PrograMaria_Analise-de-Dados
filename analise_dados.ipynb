# %% [markdown]
# #  **ANÁLISE DE DADOS** - State of Data 2022

# %% [markdown]
# ---

# %% [markdown]
# # **--- Introdução**
#
# Neste notebook, comecei a estudar com a PrograMaria sobre a área de análise de dados com o uso de Google Colab, com as bibliotecas: *`Pandas`, `Numpy`, `Matplot`* e *`Scipy`*. Tentando entender todas as funções dessas bibliotecas, ao longo dos módulos, formamos uma análise dos nossos dados.

# %% [markdown]
# # **Importações**

# %%
# Importações
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import chi2_contingency

# %% [markdown]
# ---

# %% [markdown]
# # 3.4: Uso da biblioteca "Pandas"

# %%
#Montando o drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_excel('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/planilha_modulo3.xlsx')
# para a leitura do arquivo. como esse é tipo excel, existem outros como read_json ou read_csv

# %%
dados # acessando os dados
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# ...          ...                               ...    ...         ...
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados.head(10) # Função para mostrar as primeiras linhas da tabela
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5           5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6           6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7           7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# 8           8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9           9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados.tail(10) # Função para mostrar as últimas linhas da tabela
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4263        4263  02ido3x5siue5if02iz2taqjmcnh58xh   26.0       25-29
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
# 4265        4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 4261  Masculino         Branca  Não
# 4262  Masculino        Amarela  Não
# 4263  Masculino          Parda  Não
# 4264  Masculino         Branca  Não
# ...

# %% [markdown]
# * Index: número de linhas em ordem, sempre começa com 0.

# %%
dados.shape # Tamanho da planilha: (linhas, colunas)
# Out:
# (4271, 28)

# %%
len(dados) # apenas linhas
# Out:
# 4271

# %%
dados.columns # nomes de todas as colunas
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados.info() # Informações das colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %%
dados.describe() # Retorna apenas colunas com valores númericos
# Out:
#         Unnamed: 0        IDADE  MUDOU DE ESTADO?      GESTOR?        SALARIO
# count  4271.000000  4197.000000       4171.000000  3694.000000    3694.000000
# mean   2135.000000    31.169168          0.806281     0.193016   10969.266919
# std    1233.075829     6.902803          0.395258     0.394719   19419.753189
# min       0.000000    18.000000          0.000000     0.000000      35.000000
# 25%    1067.500000    26.000000          1.000000     0.000000    4269.500000
# 50%    2135.000000    30.000000          1.000000     0.000000    7625.500000
# 75%    3202.500000    35.000000          1.000000     0.000000   12778.500000
# max    4270.000000    54.000000          1.000000     1.000000  485191.000000

# %% [markdown]
# # 3.5: Repetindo a primeira análise - Parte 1
#
# Por aqui, começamos a explorar as primeiras funções para analisarmos os nossos dados como um todo.

# %%
dados.columns # Visualizar os nomes das colunas
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados['GENERO'] # Acessando apenas uma coluna
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
dados[dados['GENERO']=='Feminino'] # Filtro
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %%
dados[dados['GENERO']!='Masculino'] # Filtro
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 562          562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528        1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913        1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925        1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554        2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090        3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357        3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493        3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610        3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171        4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200        4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227        4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
# ...

# %%
dados[dados['IDADE'] >= 30] # Filtrar por condição/números
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados[(dados['IDADE'] > 30) & (dados['GENERO'] == 'Feminino')]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 14            14  zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39
# 23            23  zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49
# ...          ...                               ...    ...         ...
# 4214        4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44
# 4221        4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34
# 4240        4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39
# 4247        4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
#
#         GENERO COR/RACA/ETNIA                   PCD  \
# 4     Feminino         Branca                   Não
# ...

# %% [markdown]
# ## Faça você mesma!

# %%
dados[dados['COR/RACA/ETNIA'] == 'Amarela']
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 13            13  zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24
# 85            85  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29
# 97            97  zbukfwxvpwlk6loglm0zbukfwx6bvyb6   40.0       40-44
# 107          107  z9toybzbja7n6xjjbz9f8hmofrry69tg   44.0       40-44
# 159          159  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39
# ...          ...                               ...    ...         ...
# 4176        4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29
# 4207        4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34
# 4210        4210  0hbwm1d1wz739r40hbwm1df6ky5kn4ap   43.0       40-44
# 4257        4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 13    Masculino        Amarela  Não
# 85     Feminino        Amarela  Não
# ...

# %%
dados[dados['IDADE'] < 40]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 6              6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21
# ...          ...                               ...    ...         ...
# 4265        4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados[(dados['IDADE'] < 40) | (dados['COR/RACA/ETNIA'] == "Amarela")]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 6              6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21
# ...          ...                               ...    ...         ...
# 4265        4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados[(dados['IDADE'] < 40) & (dados['COR/RACA/ETNIA'] == "Amarela")]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 13            13  zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24
# 85            85  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29
# 159          159  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39
# 170          170  yri3z491ejizlpj9ylu2k3jyri3z4915   34.0       30-34
# 195          195  yjbpxmkqz5yidh5oszyjbpxmkgcb1zd9   32.0       30-34
# ...          ...                               ...    ...         ...
# 3947        3947  2tnsh0gxdu3aq4z2d2tnsh0hk15brx7q   31.0       30-34
# 4058        4058  1t3ndwx8j50k0bz1t3ndwxdpwyg17c2k   27.0       25-29
# 4176        4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29
# 4207        4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 13    Masculino        Amarela  Não
# 85     Feminino        Amarela  Não
# ...

# %% [markdown]
# # Testando funções novas

# %%
dados['COR/RACA/ETNIA'].nunique()
# Out:
# 7

# %%
dados['COR/RACA/ETNIA'].tail(25)
# Out:
# 4246      Parda
# 4247     Branca
# 4248     Branca
# 4249     Branca
# 4250     Branca
# 4251      Preta
# 4252      Parda
# 4253     Branca
# 4254     Branca
# 4255      Preta
# 4256      Parda
# 4257    Amarela
# 4258     Branca
# 4259     Branca
# 4260      Parda
# 4261     Branca
# 4262    Amarela
# 4263      Parda
# 4264     Branca
# 4265     Branca
# 4266     Branca
# 4267     Branca
# 4268     Branca
# 4269     Branca
# 4270     Branca
# Name: COR/RACA/ETNIA, dtype: object

# %%
dados.groupby('ESTADO ONDE MORA')['REGIAO ONDE MORA'].nunique() # Agrupamentos de valores por 'unico'
# Out:
# ESTADO ONDE MORA
# Alagoas (AL)                1
# Amazonas (AM)               1
# Bahia (BA)                  1
# Ceará (CE)                  1
# Distrito Federal (DF)       1
# Espírito Santo (ES)         1
# Goiás (GO)                  1
# Maranhão (MA)               1
# Mato Grosso (MT)            1
# Mato Grosso do Sul (MS)     1
# Minas Gerais (MG)           1
# Paraná (PR)                 1
# Paraíba (PB)                1
# Pará (PA)                   1
# Pernambuco (PE)             1
# Piauí (PI)                  1
# Rio Grande do Norte (RN)    1
# Rio Grande do Sul (RS)      1
# Rio de Janeiro (RJ)         1
# Santa Catarina (SC)         1
# Sergipe (SE)                1
# São Paulo (SP)              1
# Name: REGIAO ONDE MORA, dtype: int64

# %%
dados['ESTADO ONDE MORA'].value_counts()
# Out:
# ESTADO ONDE MORA
# São Paulo (SP)              1745
# Minas Gerais (MG)            478
# Rio de Janeiro (RJ)          338
# Paraná (PR)                  309
# Rio Grande do Sul (RS)       204
# Bahia (BA)                   162
# Santa Catarina (SC)          156
# Distrito Federal (DF)        132
# Pernambuco (PE)              120
# Ceará (CE)                    95
# Espírito Santo (ES)           81
# Goiás (GO)                    55
# Paraíba (PB)                  42
# Rio Grande do Norte (RN)      38
# Pará (PA)                     35
# Alagoas (AL)                  32
# Sergipe (SE)                  28
# Maranhão (MA)                 28
# Amazonas (AM)                 26
# Mato Grosso (MT)              19
# Piauí (PI)                    17
# Mato Grosso do Sul (MS)       16
# Name: count, dtype: int64

# %% [markdown]
# # [Mais funções no Pandas](https://youtu.be/d5DPDxpjMN0?si=CXJ6Pjfby91-22TW)

# %%
dados['COR/RACA/ETNIA'].unique()
# Out:
# array(['Parda', 'Branca', 'Amarela', 'Preta', 'Prefiro não informar',
#        'Indígena', 'Outra'], dtype=object)

# %% [markdown]
# # 3.5: Repetindo a primeira análise - Parte 2
#
# Continuamos a abordar outras funções utéis do Pandas que usaremos bastante mais para frente.

# %%
dados.groupby('GENERO')['ID'].nunique() # Agrupamentos de valores
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby('GENERO', dropna=False )['ID'].nunique() # Agrupamentos de valores por valores únicos (ID)
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].value_counts(dropna = False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados['IDADE']>30) & (dados['GENERO'] == 'Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
pd.pivot_table(dados, values=['ID'], index = ['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %%
# pd.crosstab(dados['ID'], dados['GENERO'], dados['GESTOR?'], aggfunc='count')

# %% [markdown]
# # 4.1. Estatistica Básica
#
# Introdução a estatística com o uso dos nossos dados, conhecendo mais funções para esse trabalho como a média, mediana, moda e etc.

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
np.sum(lista_idades) # soma
# Out:
# np.int64(328)

# %%
len(lista_idades) # quantidade
# Out:
# 11

# %%
np.sum(lista_idades)/len(lista_idades)
# Out:
# np.float64(29.818181818181817)

# %%
media = np.mean(lista_idades)
print("Média aritmética:", media)
# Out:
# Média aritmética: 29.818181818181817

# %%
lista_idades.sort() # ordena a lista
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23, 100]

# %%
lista_idades.sort() # ordena a lista
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43, 100]

# %%
mediana = np.median(lista_idades) # mediana = meio da lista
mediana
# Out:
# np.float64(30.5)

# %% [markdown]
# #### Voltando para a tabela

# %%
dados['IDADE'].mean() # usando o pandas (média)
# Out:
# np.float64(31.169168453657374)

# %%
dados['IDADE'].median() # mediana em pandas
# Out:
# 30.0

# %%
dados['IDADE'].mode() # moda = quem mais aparece?
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
dados['IDADE'].std() # desvio padrão - o quão distante está de zero
# Out:
# 6.902802832143141

# %%
dados['IDADE'].min() #idade minima
# Out:
# 18.0

# %%
dados['IDADE'].max() #idade maxima
# Out:
# 54.0

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean() # média de quem do genero fem
# Out:
# np.float64(31.318051575931232)

# %%
dados[dados['GENERO']=='Masculino']['IDADE'].mean() # média de quem do genero masc
# Out:
# np.float64(31.147876077930373)

# %% [markdown]
# ## Exercício com salário

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
media_salarial = dados['SALARIO'].mean()
print(media_salarial)
# Out:
# 10969.26691932864

# %%
mediana = dados['SALARIO'].median()
print(mediana)
# Out:
# 7625.5

# %%
moda = dados['SALARIO'].mode()
print("Moda? ", moda)
# Out:
# Moda?  0    11159.0
# Name: SALARIO, dtype: float64

# %%
dados[dados['GENERO']=='Feminino']['SALARIO'].mean() # média de quem do genero fem
# Out:
# np.float64(8673.22460496614)

# %%
dados[dados['GENERO']=='Masculino']['SALARIO'].mean()
# Out:
# np.float64(11724.552688172043)

# %% [markdown]
# # 4.2 Valores Faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# ## Trabalhando com gênero - PARTE 1

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique() # contar os valores nulos por ID na coulna GENERO
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'] = dados['GENERO'].fillna('Prefiro não informar') # preencher os nulos

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ## Trabalhando com idade - PARTE 2

# %%
dados['IDADE'].isnull() # mostra se é nulo ou não
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4266    False
# 4267    False
# 4268    False
# 4269     True
# 4270    False
# Name: IDADE, Length: 4271, dtype: bool

# %%
dados['IDADE'].isnull().value_counts() #true = valores nulos
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %% [markdown]
# Tentanto fazer o filtro e média das idades

# %% [markdown]
# ### Mais jovens

# %%
cand = dados[(dados['IDADE'] >= 17) & (dados['IDADE'] <= 21)]['IDADE'].value_counts()
cand.sum()
# Out:
# np.int64(146)

# %%
len(dados[(dados['IDADE'] >= 17) & (dados['IDADE'] <= 21)]['IDADE'])
# Out:
# 146

# %%
total = dados[(dados['IDADE'] >= 17) & (dados['IDADE'] <= 21)]['IDADE'].sum()
total
# Out:
# np.float64(2950.0)

# %%
total/cand.sum()
# Out:
# np.float64(20.205479452054796)

# %% [markdown]
# ### Solução

# %%
#media_17_21 = dados[(dados['IDADE'] >= 17) & (dados['IDADE'] <= 21)]['IDADE'].mean()
# ou eu poderia ter feito dessa forma
media_17_21 = dados[dados['FAIXA IDADE'] == '17-21']['IDADE'].mean()
print(media_17_21)
moda = dados[dados['FAIXA IDADE'] == '17-21']['IDADE'].mode()
print('MODA DAORA: ', moda)
# Out:
# 20.205479452054796
# MODA DAORA:  0    21.0
# Name: IDADE, dtype: float64

# %%
dados.loc[(dados['FAIXA IDADE']=='17-21') & (dados['IDADE'].isnull()), 'IDADE'] = media_17_21

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %% [markdown]
# ### Mais velhos

# %%
len(dados[(dados['IDADE'] >= 55)])
# Out:
# 0

# %%
print(media_17_21)
# Out:
# 20.205479452054796

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4203
# True       68
# Name: count, dtype: int64

# %%
dados[dados['FAIXA IDADE'] == '55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados['FAIXA IDADE'] == '55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral_55 = dados['IDADE'].mean()
print(media_geral_55)
# Out:
# 31.153517220250375

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()), 'IDADE'] = media_geral_55

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()), 'IDADE']
# Out:
# Series([], Name: IDADE, dtype: float64)

# %% [markdown]
# ### Dados já preenchidos!

# %%
dados.loc[(dados['FAIXA IDADE']=='55+'), 'IDADE']
# Out:
# 9       31.153517
# 66      31.153517
# 96      31.153517
# 121     31.153517
# 156     31.153517
#           ...
# 4001    31.153517
# 4043    31.153517
# 4048    31.153517
# 4061    31.153517
# 4215    31.153517
# Name: IDADE, Length: 68, dtype: float64

# %%
dados.loc[(dados['FAIXA IDADE']=='17-21'), 'IDADE']
# Out:
# 6       21.000000
# 44      18.000000
# 114     20.000000
# 136     21.000000
# 194     21.000000
#           ...
# 4177    20.205479
# 4178    21.000000
# 4189    19.000000
# 4190    20.000000
# 4269    20.205479
# Name: IDADE, Length: 152, dtype: float64

# %% [markdown]
# ## Trabalhando com salário - PARTE 3

# %%
dados[dados['SALARIO'].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
dados[dados['SALARIO'].isnull()]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
mediana_salario = dados['SALARIO'].median()
print(mediana_salario)
# Out:
# 7625.5

# %%
dados.loc[dados['SALARIO'].isnull(), 'SALARIO'] = mediana_salario

# %%
dados[dados['SALARIO'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, IDADE, FAIXA IDADE, GENERO, COR/RACA/ETNIA, PCD, EXPERIENCIA_PROFISSIONAL_PREJUDICADA, ASPECTOS_PREJUDICADOS, VIVE_NO_BRASIL, ESTADO ONDE MORA, UF ONDE MORA, REGIAO ONDE MORA, MUDOU DE ESTADO?, REGIAO DE ORIGEM, NIVEL DE ENSINO, ÁREA DE FORMAÇÃO, QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?, SETOR, NUMERO DE FUNCIONARIOS, GESTOR?, CARGO COMO GESTOR, CARGO ATUAL, NIVEL, FAIXA SALARIAL, QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?, QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?, SALARIO]
# Index: []
#
# [0 rows x 28 columns]

# %%
dados.loc[dados['SALARIO'] == 7625.5, ['ID']]
# Out:
#                                     ID
# 12    zwr9hqcpg513kaopenzwr9hibaqmldto
# 28    ztgepgj82o9oix0nztgepq2trcay6gpv
# 34    zsa9i6njd3e594mw0tvlk4zsa9iw86i9
# 39    zr4b2vm7dapp3linwqwn7zr4b2vmagqx
# 63    zm7o5yquakof0j6zm7vh3o0letznhdvh
# ...                                ...
# 4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma
# 4252  064pe9b1htw7mflhif064pe95dotv6yf
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw
# 4260  03atvow8404tatt2iixjds03atvownkz
# 4261  02xomoejng6c9152kde02xomww412qpg
#
# [577 rows x 1 columns]

# %% [markdown]
# # 4.3 Tratando valores discrepantes

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 400, 20, 43, 31, 23]

# %%
media = np.mean(lista_idades)
media
# Out:
# np.float64(62.54545454545455)

# %%
desvio = np.std(lista_idades) # desvio padrão
desvio
# Out:
# np.float64(106.89532997398872)

# %%
media + 3*desvio
# Out:
# np.float64(383.2314444674207)

# %%
media - 3*desvio
# Out:
# np.float64(-258.1405353765116)

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e9cde3c64b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e9cde3c6a80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e9cde3c5970>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e9cde3c70b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e9cde3c7380>],
#  'means': []}

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e9cde400350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e9cde400890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e9cde76ffe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e9cde400e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e9cde401220>],
#  'means': []}

# %%
Q1 = dados['SALARIO'].quantile(0.25)
Q1
# Out:
# np.float64(4751.5)

# %%
Q3 = dados['SALARIO'].quantile(0.75)
Q3
# Out:
# np.float64(11794.5)

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(7043.0)

# %%
lim_superior = Q3 + (1.5 * IQR)
lim_superior
# Out:
# np.float64(22359.0)

# %%
lim_inferior = Q1 - (1.5 * IQR)
lim_inferior
# Out:
# np.float64(-5813.0)

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salarial = dados['SALARIO'].mean()
media_salarial
# Out:
# np.float64(10517.53348162023)

# %%
desvio_salario = dados['SALARIO'].std()
desvio_salario
# Out:
# 18096.210989118474

# %%
limite_superior = media_salarial + (3*desvio_salario)
limite_superior
# Out:
# np.float64(64806.16644897565)

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %%
media_30_40 = dados[(dados['FAIXA SALARIAL'] == 'de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()
media_30_40
# Out:
# np.float64(39002.19402985075)

# %%
dados.loc[(dados['FAIXA SALARIAL'] == 'de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_30_40

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
media_acima_40 = dados[(dados['FAIXA SALARIAL'] == 'Acima de R$ 40.001/mês') & (dados['SALARIO'] < limite_superior)]['SALARIO'].mean()
media_acima_40
# Out:
# np.float64(53127.846153846156)

# %%
dados.loc[(dados['FAIXA SALARIAL'] == 'Acima de R$ 40.001/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_acima_40

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e9cde483680>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e9cde5942f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e9cde483530>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e9cde594800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e9cde594ad0>],
#  'means': []}

# %% [markdown]
# # 4.4 Intervalo de confiança e Distribuição amostral

# %%
salarios = dados['SALARIO']

# %%
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
media_amostral = np.mean(salarios)
media_amostral
# Out:
# np.float64(9904.390109813306)

# %%
desvio_amostral = np.std(salarios)
desvio_amostral #temos uma amostrada bem variada considerando a média amostral
# Out:
# 8306.104872579343

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# np.float64(127.11109872023638)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9655.186295869078), np.float64(10153.593923757535))

# %% [markdown]
# ## Desafio no final da aula

# %% [markdown]
# ## Idade

# %%
nv_conf = 0.95

# %%
idades = dados['IDADE']
idades
# Out:
# 0       39.000000
# 1       32.000000
# 2       53.000000
# 3       27.000000
# 4       46.000000
#           ...
# 4266    26.000000
# 4267    30.000000
# 4268    29.000000
# 4269    20.205479
# 4270    24.000000
# Name: IDADE, Length: 4271, dtype: float64

# %%
media_amostral_id = np.mean(idades)
media_amostral_id
# Out:
# np.float64(31.153517220250375)

# %%
desvio_amostral_id = np.std(idades)
desvio_amostral_id
# Out:
# 6.854238421066827

# %%
tamanho_amostra_id = len(idades)
tamanho_amostra_id
# Out:
# 4271

# %%
erro_padrao_id = stats.sem(idades)
erro_padrao_id
# Out:
# np.float64(0.10489270120685477)

# %%
intervalo_confianca_id = stats.t.interval(nv_conf, tamanho_amostra_id-1, loc=media_amostral_id, scale=erro_padrao_id)
intervalo_confianca_id
# Out:
# (np.float64(30.947873012475945), np.float64(31.359161428024805))

# %% [markdown]
# ## Média salarial: por cargo

# %%
cargo = dados.groupby('CARGO ATUAL')
cargo

# %%
media_amostral_cargo = cargo['SALARIO'].mean()
media_amostral_cargo
# Out:
# CARGO ATUAL
# Analista de BI/BI Analyst                                               6302.277778
# Analista de Dados/Data Analyst                                          7425.715180
# Analista de Inteligência de Mercado/Market Intelligence                 5646.241379
# Analista de Marketing                                                   4984.842105
# Analista de Negócios/Business Analyst                                   8043.439024
# Analista de Suporte/Analista Técnico                                    4034.361111
# Analytics Engineer                                                     11784.140659
# Cientista de Dados/Data Scientist                                      10429.105562
# DBA/Administrador de Banco de Dados                                     9399.166667
# Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas             7293.509434
# Economista                                                              7326.875000
# ...

# %%
desvio_amostral_cargo = cargo['SALARIO'].std()
desvio_amostral_cargo
# Out:
# CARGO ATUAL
# Analista de BI/BI Analyst                                               4573.410844
# Analista de Dados/Data Analyst                                          5615.134109
# Analista de Inteligência de Mercado/Market Intelligence                 3190.805190
# Analista de Marketing                                                   3040.558104
# Analista de Negócios/Business Analyst                                   4981.653681
# Analista de Suporte/Analista Técnico                                    3079.767388
# Analytics Engineer                                                      8452.563216
# Cientista de Dados/Data Scientist                                       7481.279090
# DBA/Administrador de Banco de Dados                                     6152.335903
# Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas             5285.999802
# Economista                                                              7342.561795
# ...

# %%
tamanho_cargo = len(cargo['SALARIO'])
tamanho_cargo
# Out:
# 18

# %%
erro_padrao_cargo = cargo['SALARIO'].sem()
erro_padrao_cargo
# Out:
# CARGO ATUAL
# Analista de BI/BI Analyst                                               235.230871
# Analista de Dados/Data Analyst                                          222.131272
# Analista de Inteligência de Mercado/Market Intelligence                 592.517649
# Analista de Marketing                                                   697.551869
# Analista de Negócios/Business Analyst                                   449.180585
# Analista de Suporte/Analista Técnico                                    362.954067
# Analytics Engineer                                                     1010.274538
# Cientista de Dados/Data Scientist                                       317.276905
# DBA/Administrador de Banco de Dados                                    1776.026395
# Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas             513.421688
# Economista                                                             1835.640449
# ...

# %%
intervalo = stats.t.interval(nv_conf, tamanho_cargo-1, loc=media_amostral_cargo, scale=erro_padrao_cargo)
intervalo
# Out:
# (array([ 5805.98402107,  6957.05916133,  4396.13841367,  3513.13630603,
#          7095.75082796,  3268.59496565,  9652.64770163,  9759.70980458,
#          5652.07851226,  6210.28435939,  3454.01218581,  9947.11916643,
#         12383.184935  ,  7168.11392061,  4220.21049447,  5745.86643524,
#          9143.90994869,  4869.06507982]),
#  array([ 6798.57153449,  7894.37119861,  6896.34434495,  6456.54790449,
#          8991.12722082,  4800.12725657, 13915.63361705, 11098.50131882,
#         13146.25482107,  8376.73450853, 11199.73781419, 11439.41898114,
#         18842.11611826, 12291.99134255,  5310.75747706,  9016.56213618,
#         14893.34495327,  9268.67405062]))

# %%
# 1. Transformamos o primeiro array (limite inferior) numa Series
# Usamos o índice da media_amostral_cargo para os nomes aparecerem
limite_inf_series = pd.Series(intervalo[0], index=media_amostral_cargo.index)

# 2. Transformamos o segundo array (limite superior) numa Series
limite_sup_series = pd.Series(intervalo[1], index=media_amostral_cargo.index)

# 3. Juntamos as duas lado a lado (axis=1)
intervalo_completo = pd.concat([limite_inf_series, limite_sup_series], axis=1)

intervalo_completo.columns = ['Limite Inferior', 'Limite Superior']
intervalo_completo
# Out:
#                                                     Limite Inferior  \
# CARGO ATUAL
# Analista de BI/BI Analyst                               5805.984021
# Analista de Dados/Data Analyst                          6957.059161
# Analista de Inteligência de Mercado/Market Inte...      4396.138414
# Analista de Marketing                                   3513.136306
# Analista de Negócios/Business Analyst                   7095.750828
# Analista de Suporte/Analista Técnico                    3268.594966
# Analytics Engineer                                      9652.647702
# Cientista de Dados/Data Scientist                       9759.709805
# DBA/Administrador de Banco de Dados                     5652.078512
# Desenvolvedor/ Engenheiro de Software/ Analista...      6210.284359
# Economista                                              3454.012186
# Engenheiro de Dados/Arquiteto de Dados/Data Eng...      9947.119166
# Engenheiro de Machine Learning/ML Engineer             12383.184935
# ...

# %% [markdown]
# ## Média salarial: por Gênero (INCOMPLETO)

# %%
genero = dados.groupby('GENERO')
genero

# %%
media_amostral_genero = genero['SALARIO'].mean()
media_amostral_genero
# Out:
# GENERO
# Feminino                 8482.256483
# Masculino               10393.555984
# Prefiro não informar     7017.595238
# Name: SALARIO, dtype: float64

# %% [markdown]
# # 4.5 Featuring engineering - parte 1

# %%
def preencher_nivel(gestor, nivel):
  if gestor == 1:
    return 'Pessoa Gestora'
  else:
    return nivel

# %%
dados['NOVO_NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x ['NIVEL']), axis=1)

# %%
dados['NOVO_NIVEL'].value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados['NIVEL']
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
dados = pd.get_dummies(dados, columns=['NIVEL'])

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39 < idade <= 58:
    return 'Geração X'
  elif 29< idade <= 39:
    return 'Millenial'
  elif 13< idade<= 29:
    return 'Geração Z'
  else:
    return 'Outra geração'

# %%
dados['GERACAO'] = dados['IDADE'].apply(determinar_geracao)

# %%
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %% [markdown]
# # Featuring engineering - parte 2

# %%
dados2 = pd.read_excel('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/Planilha_Aula_parte2.xlsx')

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %%
dados = dados.merge(dados2, on='ID', how='left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
dados['EM BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
dados['EM BUSCA'].value_counts()
# Out:
# EM BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados['ABERTO_OPORTUNIDADES'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
dados['ABERTO_OPORTUNIDADES'].value_counts()
# Out:
# ABERTO_OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# ## Desafio proposto
#
#
# *   Criar nova coluna de etnias
# *   Simplificar para branca, não branca e outros e criar novas variáveis

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
dados['COR/RACA/ETNIA'].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
def determinar_etnia(etnia):
  if etnia == 'Branca':
    return 'Branca'
  elif etnia == 'Prefiro não informar':
    return 'Não informado'
  else:
    return 'Não branca'

# %%
dados['ETNIA'] = dados['COR/RACA/ETNIA'].apply(determinar_etnia)

# %%
dados['ETNIA'].value_counts()
# Out:
# ETNIA
# Branca           2746
# Não branca       1501
# Não informado      26
# Name: count, dtype: int64

# %%
dados
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# ...          ...                               ...        ...         ...
# 4268        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
# 4270        4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29
# 4271        4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21
# 4272        4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# ...

# %% [markdown]
# # 4.6 Correlação

# %% [markdown]
# Correlação mais usada: Pearson

# %% [markdown]
# 1. Correlação entre variáveis numéricas

# %%
correlacao_continua = dados['IDADE'].corr(dados['SALARIO'])
correlacao_continua # não é uma relação muito forte por estar mais proximo de 0
# Out:
# np.float64(0.2902441968622099)

# %% [markdown]
# 2. Correlação entre variáveis discretas

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# a correlação ficou proximo de zero, pois na nossa tabela de TI, muitos tem formação.
# em nossa realidade, isso não é verdade
# Out:
# np.float64(0.04499106580480143)

# %%
tabela_cruzada = pd.crosstab(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# ...

# %%
np.array(tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# ## Outra análise
#
#
# *   Será que tem correlação entre nivel de ensino a gênero?

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
tabela_cruzada2 = pd.crosstab(dados['GENERO'], dados['NIVEL DE ENSINO'])
tabela_cruzada2
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# GENERO
# Feminino                            57                     104
# Masculino                          134                     506
# Prefiro não informar                 0                       3
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# GENERO
# Feminino                                365       133
# Masculino                              1138       386
# Prefiro não informar                      7         2
#
# NIVEL DE ENSINO       Não tenho graduação formal  Prefiro não informar  \
# GENERO
# Feminino                                      24                     3
# Masculino                                     86                     8
# Prefiro não informar                           0                     1
#
# NIVEL DE ENSINO       Pós-graduação
# GENERO
# Feminino                        372
# Masculino                       936
# Prefiro não informar              8

# %%
def cramer_coeficiente2(coluna1, coluna2):
  tabela_cruzada2 = np.array(pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada2)[0]
  soma = np.sum(tabela_cruzada2)
  mini = min(tabela_cruzada2.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente2(dados['GENERO'], dados['NIVEL DE ENSINO']) # não temos!
# Out:
# np.float64(0.076119232802818)

# %% [markdown]
# # **--- Finalização**

# %%
dados.to_csv('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/analise_dados.csv', index=False)

# %% [markdown]
# # Conectando SQL com o Pandas

# %% [markdown]
# ---

# %%
import sqlite3

# %%
conexao = sqlite3.connect('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/status_brasil')

# %%
query = " SELECT * FROM Municipios_Brasileiros WHERE Cidade ='Itaquaquecetuba'; "
query
# Out:
# " SELECT * FROM Municipios_Brasileiros WHERE Cidade ='Itaquaquecetuba'; "

# %%
pd.read_sql(query, con=conexao)
# Out:
#             Cidade Estado   Regiao  Municipio_ID
# 0  Itaquaquecetuba     SP  Sudeste          5043

# %% [markdown]
# ## Entendendo as strings

# %% [markdown]
# ---

# %%
a = 'batata'

# %%
print("Eu gosto de {}".format(a))
# Out:
# Eu gosto de batata

# %%
a = ['batata', 'tomate', 'alface']

# %%
print('eu gosto de {}, {} e {}'.format(a[0], a[1], a[2]))
# Out:
# eu gosto de batata, tomate e alface

# %%
print('eu gosto de {}'.format(', '.join(a)))
# Out:
# eu gosto de batata, tomate, alface

# %% [markdown]
# ---

# %%
dados = pd.read_csv('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/analise_dados.csv')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
lista_estados = list(dados['UF ONDE MORA'].unique()) # List = transforma array em lista

# %%
query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) FROM Municipios_Brasileiros
        INNER JOIN Municipio_Status ON Municipios_Brasileiros.Municipio_ID = Municipio_Status.Municipio_ID
        WHERE Municipios_Brasileiros.Estado in ({})
        GROUP BY Municipios_Brasileiros.Estado;'''.format(', '.join(['?' for _ in lista_estados]))
  # AVG = média

# %%
print(query)
# Out:
# SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) FROM Municipios_Brasileiros
#         INNER JOIN Municipio_Status ON Municipios_Brasileiros.Municipio_ID = Municipio_Status.Municipio_ID
#         WHERE Municipios_Brasileiros.Estado in (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
#         GROUP BY Municipios_Brasileiros.Estado;

# %%
estados_renda = pd.read_sql(query, con=conexao, params = lista_estados)

# %%
dados.rename(columns={'UF ONDE MORA': 'Estado'}, inplace=True)

# %%
dados = dados.merge(estados_renda, on='Estado', how='left')

# %%
correlacao_renda_salario = dados['SALARIO'].corr(dados['AVG(Municipio_Status.renda)'])
correlacao_renda_salario
# Out:
# np.float64(0.12083384881429463)

# %% [markdown]
# ## Faça você mesma!

# %%
query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.educacao) FROM Municipios_Brasileiros
        INNER JOIN Municipio_Status ON Municipios_Brasileiros.Municipio_ID = Municipio_Status.Municipio_ID
        WHERE Municipios_Brasileiros.Estado in ({})
        GROUP BY Municipios_Brasileiros.Estado;'''.format(', '.join(['?' for _ in lista_estados]))

# %%
print(query)
# Out:
# SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.educacao) FROM Municipios_Brasileiros
#         INNER JOIN Municipio_Status ON Municipios_Brasileiros.Municipio_ID = Municipio_Status.Municipio_ID
#         WHERE Municipios_Brasileiros.Estado in (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
#         GROUP BY Municipios_Brasileiros.Estado;

# %%
estados_educacao = pd.read_sql(query, con=conexao, params = lista_estados)

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
dados.rename(columns={'NIVEL DE ENSINO': 'Educacao'}, inplace=True)

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'Educacao', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
dados = dados.merge(estados_educacao, on='Estado', how='left')

# %%
correlacao_renda_educacao = dados['SALARIO'].corr(dados['AVG(Municipio_Status.educacao)'])
correlacao_renda_educacao
# Out:
# np.float64(0.15558020288268756)

# %% [markdown]
# #  **--- Visualização de Dados**

# %%
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/analise_dados.csv')

# %%
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
genero_counts = dados['GENERO'].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure() #matplot
plt.bar(height = genero_counts.values, x = genero_counts.index)
plt.title('Quantidade de pessoas por gênero na área de Dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure() #seaborn
sns.countplot(data = dados, x = 'GENERO', palette = 'pastel')
plt.title('Quantidade de pessoas por gênero na área de Dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_11619/1697879967.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = dados, x = 'GENERO', palette = 'pastel')

# %%
dados['IDADE'].head(30)
# Out:
# 0     39.000000
# 1     32.000000
# 2     53.000000
# 3     27.000000
# 4     46.000000
# 5     32.000000
# 6     21.000000
# 7     31.000000
# 8     33.000000
# 9     31.153517
# 10    25.000000
# 11    33.000000
# 12    31.000000
# 13    24.000000
# 14    35.000000
# 15    28.000000
# 16    31.000000
# 17    29.000000
# 18    28.000000
# 19    26.000000
# 20    37.000000
# 21    33.000000
# 22    26.000000
# 23    46.000000
# 24    34.000000
# 25    27.000000
# 26    25.000000
# 27    27.000000
# 28    24.000000
# 29    25.000000
# Name: IDADE, dtype: float64

# %%
'''dados['SALARIO'] = pd.to_numeric(dados['SALARIO'], errors='coerce')
dados['IDADE'] = pd.to_numeric(dados['IDADE'], errors='coerce')'''
# Out:
# "dados['SALARIO'] = pd.to_numeric(dados['SALARIO'], errors='coerce')\ndados['IDADE'] = pd.to_numeric(dados['IDADE'], errors='coerce')"

# %%
salario_por_idade = dados.groupby("IDADE")['SALARIO'].mean()
salario_por_idade
# Out:
# IDADE
# 18.000000     4230.307692
# 19.000000     4519.590909
# 20.000000     5004.272727
# 20.205479     3536.000000
# 21.000000     4578.737179
# 22.000000     4394.689815
# 23.000000     5602.406897
# 24.000000     6151.622449
# 25.000000     7616.392336
# 26.000000     7700.071174
# 27.000000     8237.429766
# 28.000000     9737.938144
# 29.000000     9554.853147
# 30.000000    10316.412686
# 31.000000    10021.462609
# 31.153517     9646.330882
# 32.000000    10843.197778
# 33.000000    11592.718590
# 34.000000    12294.640212
# 35.000000    12435.845105
# 36.000000    12267.966533
# 37.000000    12613.528357
# 38.000000    13802.724874
# 39.000000    13309.082898
# 40.000000    15028.032721
# 41.000000    13578.880952
# 42.000000    11801.037037
# 43.000000    14349.732278
# 44.000000    14665.770147
# 45.000000    16103.431520
# 46.000000    11913.709677
# 47.000000    11156.031250
# 48.000000    12249.714286
# 49.000000    14556.000000
# 50.000000    15740.010181
# ...

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker='o', linestyle='--')
plt.xlabel("idade")
plt.ylabel("Média de Salário")
plt.grid(True)
plt.title("Média de salário por idade")
plt.show()

# %%
import plotly.express as px

# %%
fig = px.line(salario_por_idade.reset_index(), x='IDADE', y='SALARIO',
              title='Média de salário por idade', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(15, 5))
plt.scatter(dados['IDADE'], dados['SALARIO'], alpha=0.5)
plt.xlabel('Idade')
plt.ylabel("Salario")
plt.title('Dispersão de idade por salário')
plt.grid(True)
plt.show()

# %%
fig = px.scatter(dados, x='IDADE', y='SALARIO', title='Dispersão de salário por idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Outros gráficos

# %% [markdown]
# ...

# %%
"""plt.pie(sizes='IDADE', labels='IDADE')
plt.show()"""
# Out:
# "plt.pie(sizes='IDADE', labels='IDADE')\nplt.show()"

# %% [markdown]
# # Faça você mesma!

# %%
dados_fvm = pd.read_csv('/content/drive/MyDrive/ESTUDOS_sarinha/ProgrMaria/municipios_brasileiros.csv')
dados_fvm # Importando e checando a tabela de municípios brasileiros
# Out:
#       codigo_ibge       nome_municipio  codigo_uf  uf          estado  \
# 0         5200050      Abadia de Goiás         52  GO           Goiás
# 1         3100104  Abadia dos Dourados         31  MG    Minas Gerais
# 2         5200100            Abadiânia         52  GO           Goiás
# 3         3100203               Abaeté         31  MG    Minas Gerais
# 4         1500107           Abaetetuba         15  PA            Pará
# ...           ...                  ...        ...  ..             ...
# 5565      2933604          Xique-Xique         29  BA           Bahia
# 5566      2517407               Zabelê         25  PB         Paraíba
# 5567      3557154             Zacarias         35  SP       São Paulo
# 5568      2114007              Zé Doca         21  MA        Maranhão
# 5569      4219853               Zortéa         42  SC  Santa Catarina
#
#       capital  latitude  longitude
# 0           0 -16.75730   -49.4412
# 1           0 -18.48310   -47.3916
# ...

# %%
dados_fvm.head(30)
# Out:
#     codigo_ibge       nome_municipio  codigo_uf  uf               estado  \
# 0       5200050      Abadia de Goiás         52  GO                Goiás
# 1       3100104  Abadia dos Dourados         31  MG         Minas Gerais
# 2       5200100            Abadiânia         52  GO                Goiás
# 3       3100203               Abaeté         31  MG         Minas Gerais
# 4       1500107           Abaetetuba         15  PA                 Pará
# 5       2300101              Abaiara         23  CE                Ceará
# 6       2900108               Abaíra         29  BA                Bahia
# 7       2900207                Abaré         29  BA                Bahia
# 8       4100103               Abatiá         41  PR               Paraná
# 9       4200051        Abdon Batista         42  SC       Santa Catarina
# 10      1500131      Abel Figueiredo         15  PA                 Pará
# 11      4200101         Abelardo Luz         42  SC       Santa Catarina
# ...

# %%
dados_fvm.tail(30)
# Out:
#       codigo_ibge       nome_municipio  codigo_uf  uf             estado  \
# 5540      1508357     Vitória do Xingu         15  PA               Pará
# 5541      4128708             Vitorino         41  PR             Paraná
# 5542      2113009      Vitorino Freire         21  MA           Maranhão
# 5543      3172103         Volta Grande         31  MG       Minas Gerais
# 5544      3306305        Volta Redonda         33  RJ     Rio de Janeiro
# 5545      3557006           Votorantim         35  SP          São Paulo
# 5546      3557105          Votuporanga         35  SP          São Paulo
# 5547      2933406               Wagner         29  BA              Bahia
# 5548      2211704          Wall Ferraz         22  PI              Piauí
# 5549      1722081         Wanderlândia         17  TO          Tocantins
# 5550      2933455            Wanderley         29  BA              Bahia
# 5551      3172202       Wenceslau Braz         31  MG       Minas Gerais
# ...

# %%
dados_fvm.columns # Verificando os nomes as colunas
# Out:
# Index(['codigo_ibge', 'nome_municipio', 'codigo_uf', 'uf', 'estado', 'capital',
#        'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# Questionamento:
# *   Quantos munícipios tem por estado? Quem tem mais?

# %%
dados_fvm['codigo_uf'].value_counts()
# Out:
# codigo_uf
# 31    853
# 35    645
# 43    497
# 29    417
# 41    399
# 42    295
# 52    246
# 22    224
# 25    223
# 21    217
# 26    185
# 23    184
# 24    167
# 15    144
# 51    141
# 17    139
# 27    102
# 33     92
# 50     79
# 32     78
# 28     75
# 13     62
# 11     52
# 12     22
# 16     16
# 14     15
# 53      1
# Name: count, dtype: int64

# %%
dados_fvm['estado'].value_counts() # Quantiade de aparições dos estados = quem tem mais municipios
# Out:
# estado
# Minas Gerais           853
# São Paulo              645
# Rio Grande do Sul      497
# Bahia                  417
# Paraná                 399
# Santa Catarina         295
# Goiás                  246
# Piauí                  224
# Paraíba                223
# Maranhão               217
# Pernambuco             185
# Ceará                  184
# Rio Grande do Norte    167
# Pará                   144
# Mato Grosso            141
# Tocantins              139
# Alagoas                102
# Rio de Janeiro          92
# Mato Grosso do Sul      79
# Espírito Santo          78
# Sergipe                 75
# Amazonas                62
# Rondônia                52
# Acre                    22
# Amapá                   16
# Roraima                 15
# Distrito Federal         1
# Name: count, dtype: int64

# %%
contagem_municipios = dados_fvm.groupby('estado')['nome_municipio'].count().sort_values(ascending=True) # Outra forma mais organizada para checar

# %% [markdown]
# Descobertas:
# *   Minas Gerais tem mais municipios;
# *   Distrito Federal não possui;
# * Roraima tem a menor quantidade

# %%
# pelo MatPlotLib: gráfico de barra na horizontal
plt.title("Quantidade de Municípios por Estado")
plt.xlabel("Quantidade de Municípios")
ax = contagem_municipios.plot(kind='barh', color='indianred')
ax.set_ylabel('')
plt.grid(True)
plt.show()

# %%
# pelo Seaborn, tentativa de mesmo gráfico
df_contagem = contagem_municipios.reset_index()
df_contagem.columns = ['Estado', 'Total de Municipios']
plt.figure(figsize=(8, 6))
sns.barplot(data=df_contagem, x="Total de Municipios", y="Estado", palette="husl")
sns.set_style('whitegrid')
# Out:
# /tmp/ipykernel_11619/1016963229.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# *Mais gráficos em breve!*
